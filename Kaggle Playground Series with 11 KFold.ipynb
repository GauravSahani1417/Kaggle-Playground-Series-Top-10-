# %%
import lightgbm as lgb
import optuna.integration.lightgbm as oplgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  0.670390  0.811300  0.643968  0.291791  0.284117  0.855953  0.890700
# 1   3  0.388053  0.621104  0.686102  0.501149  0.643790  0.449805  0.510824
# 2   4  0.834950  0.227436  0.301584  0.293408  0.606839  0.829175  0.506143
# 3   5  0.820708  0.160155  0.546887  0.726104  0.282444  0.785108  0.752758
# 4   8  0.935278  0.421235  0.303801  0.880214  0.665610  0.830131  0.487113
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14  \
# 0  0.285542  0.558245  0.779418  0.921832  0.866772  0.878733  0.305411
# 1  0.580748  0.418335  0.432632  0.439872  0.434971  0.369957  0.369484
# 2  0.558771  0.587603  0.823312  0.567007  0.677708  0.882938  0.303047
# 3  0.823267  0.574466  0.580843  0.769594  0.818143  0.914281  0.279528
# 4  0.604157  0.874658  0.863427  0.983575  0.900464  0.935918  0.435772
#
#      target
# 0  7.243043
# 1  8.203331
# 2  7.776091
# 3  6.957716
# 4  7.951046

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   0  0.353600  0.738780  0.600939  0.293377  0.285691  0.458006  0.620704
# 1   2  0.907222  0.189756  0.215531  0.869915  0.301333  0.528958  0.390351
# 2   6  0.179287  0.355353  0.623972  0.437812  0.282476  0.320826  0.386789
# 3   7  0.359385  0.181049  0.551368  0.206386  0.280763  0.482076  0.506677
# 4  10  0.335791  0.682607  0.676481  0.219465  0.282861  0.581721  0.748639
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14
# 0  0.422249  0.369203  0.435727  0.550540  0.699134  0.286864  0.364515
# 1  0.521112  0.794779  0.798580  0.446475  0.449037  0.916964  0.513002
# 2  0.776422  0.222268  0.229102  0.211913  0.222651  0.327164  0.827941
# 3  0.362793  0.379737  0.345686  0.445276  0.518485  0.299028  0.598166
# 4  0.350158  0.448915  0.506878  0.817721  0.805895  0.790591  0.249275

# %%
df_sample = pd.read_csv('sample_submission_Play.csv')

# %%
train_id = df_train["id"]
test_id = df_test["id"]

df_train.drop("id", axis=1, inplace=True)
df_test.drop("id", axis=1, inplace=True)

# %%
# df_train['contG'] = df_train['cont1'] * df_train['cont7']
# df_test['contG'] = df_test['cont1'] * df_test['cont7']

# df_train['contS'] = df_train['cont2'] * df_train['cont9']
# df_test['contS'] = df_test['cont2'] * df_test['cont9']

# df_train['contR'] = df_train['cont3'] * df_train['cont11']
# df_test['contR'] = df_test['cont3'] * df_test['cont11']

# %%
#Adding all features except Target column
feature_cols = [c for c in df_train.columns if c != "target"]

# %%
feature_cols
# Out:
# ['cont1',
#  'cont2',
#  'cont3',
#  'cont4',
#  'cont5',
#  'cont6',
#  'cont7',
#  'cont8',
#  'cont9',
#  'cont10',
#  'cont11',
#  'cont12',
#  'cont13',
#  'cont14']

# %%
train_x = df_train[feature_cols]
train_y = df_train.target
test_x = df_test

# %%
folds = KFold(n_splits=10, shuffle=True, random_state=33)

# %%
class FoldsAverageLGBM:
    def __init__(self, folds):
        self.folds = folds
        self.models = []
        
    def fit(self, lgb_params, train_x, train_y):
        oof_preds = np.zeros_like(train_y)
        
        self.train_x = train_x.values
        self.train_y = train_y.values
        
        for tr_idx, va_idx in tqdm(folds.split(train_x)):
            tr_x, va_x = self.train_x[tr_idx], self.train_x[va_idx]
            tr_y, va_y = self.train_y[tr_idx], self.train_y[va_idx]
            
            lgb_train_dataset = lgb.Dataset(tr_x, tr_y)
            lgb_valid_dataset = lgb.Dataset(va_x, va_y)
            model = lgb.train(lgb_params, lgb_train_dataset, valid_sets=[lgb_valid_dataset], verbose_eval=100)
            self.models.append(model)
            
            oof_pred = model.predict(va_x)
            oof_preds[va_idx] = oof_pred
            
        self.oof_preds = oof_preds
        
    def predict(self, test_x):
        preds = []
        for model in tqdm(self.models):
            pred = model.predict(test_x)
            preds.append(pred)
        preds = np.mean(preds, axis=0)
        return preds

# %%
best_lgb_params = {
 'random_state': 33,'n_estimators':5000,
 'min_data_per_group': 5,
 'boosting_type': 'gbdt',
 'num_leaves': 256,
 'num_iterations' : 5000,
 'max_dept': -1,
 'learning_rate': 0.0046,
 'subsample_for_bin': 200000,
 'lambda_l1': 1.074622455507616e-05,
 'lambda_l2': 2.0521330798729704e-06,
 'n_jobs': -1,
 'cat_smooth': 1.0,
 'silent': True,
 'importance_type': 'split',
 'metric': 'rmse',
 'feature_pre_filter': False,
 'bagging_fraction': 0.8206341150202605,
 'min_data_in_leaf': 100,
 'min_sum_hessian_in_leaf': 0.001,
 'bagging_freq': 6,
 'feature_fraction': 0.5,
 'min_gain_to_split': 0.0,
 'min_child_samples': 20
}
#best_lgb_params["learning_rate"] = 0.001
best_lgb_params["early_stopping_round"] = 1000
best_lgb_params["num_iterations"] = 18000

# %%
folds_average_lgbm = FoldsAverageLGBM(folds)

# %%
folds_average_lgbm.fit(best_lgb_params, train_x, train_y)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# D:\anaconda\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\anaconda\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\anaconda\lib\site-packages\lightgbm\basic.py:842: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.719856
# [200]	valid_0's rmse: 0.712646
# [300]	valid_0's rmse: 0.707904
# [400]	valid_0's rmse: 0.704813
# [500]	valid_0's rmse: 0.702675
# [600]	valid_0's rmse: 0.701053
# [700]	valid_0's rmse: 0.699775
# [800]	valid_0's rmse: 0.698808
# [900]	valid_0's rmse: 0.697955
# [1000]	valid_0's rmse: 0.697326
# [1100]	valid_0's rmse: 0.69678
# [1200]	valid_0's rmse: 0.696334
# [1300]	valid_0's rmse: 0.696002
# [1400]	valid_0's rmse: 0.695732
# [1500]	valid_0's rmse: 0.695508
# [1600]	valid_0's rmse: 0.69529
# [1700]	valid_0's rmse: 0.69514
# [1800]	valid_0's rmse: 0.694988
# [1900]	valid_0's rmse: 0.69488
# [2000]	valid_0's rmse: 0.694783
# [2100]	valid_0's rmse: 0.694694
# [2200]	valid_0's rmse: 0.694635
# [2300]	valid_0's rmse: 0.694553
# [2400]	valid_0's rmse: 0.6945
# [2500]	valid_0's rmse: 0.694455
# [2600]	valid_0's rmse: 0.694399
# [2700]	valid_0's rmse: 0.694356
# [2800]	valid_0's rmse: 0.694349
# [2900]	valid_0's rmse: 0.694315
# [3000]	valid_0's rmse: 0.694297
# [3100]	valid_0's rmse: 0.694282
# [3200]	valid_0's rmse: 0.694253
# [3300]	valid_0's rmse: 0.694268
# [3400]	valid_0's rmse: 0.694276
# [3500]	valid_0's rmse: 0.694271
# [3600]	valid_0's rmse: 0.69427
# [3700]	valid_0's rmse: 0.694302
# [3800]	valid_0's rmse: 0.694294
# [3900]	valid_0's rmse: 0.694325
# [4000]	valid_0's rmse: 0.694345
# [4100]	valid_0's rmse: 0.694369
# [4200]	valid_0's rmse: 0.694383
# Early stopping, best iteration is:
# [3225]	valid_0's rmse: 0.694241
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.72139
# [200]	valid_0's rmse: 0.714399
# [300]	valid_0's rmse: 0.709779
# [400]	valid_0's rmse: 0.706743
# [500]	valid_0's rmse: 0.704551
# [600]	valid_0's rmse: 0.702895
# [700]	valid_0's rmse: 0.70158
# [800]	valid_0's rmse: 0.700535
# [900]	valid_0's rmse: 0.699691
# [1000]	valid_0's rmse: 0.698965
# [1100]	valid_0's rmse: 0.698351
# [1200]	valid_0's rmse: 0.697844
# [1300]	valid_0's rmse: 0.697425
# [1400]	valid_0's rmse: 0.697084
# [1500]	valid_0's rmse: 0.696812
# [1600]	valid_0's rmse: 0.696613
# [1700]	valid_0's rmse: 0.696419
# [1800]	valid_0's rmse: 0.696249
# [1900]	valid_0's rmse: 0.696118
# [2000]	valid_0's rmse: 0.695983
# [2100]	valid_0's rmse: 0.695873
# [2200]	valid_0's rmse: 0.695776
# [2300]	valid_0's rmse: 0.695698
# [2400]	valid_0's rmse: 0.695623
# [2500]	valid_0's rmse: 0.695551
# [2600]	valid_0's rmse: 0.695477
# [2700]	valid_0's rmse: 0.695444
# [2800]	valid_0's rmse: 0.695405
# [2900]	valid_0's rmse: 0.695399
# [3000]	valid_0's rmse: 0.69534
# [3100]	valid_0's rmse: 0.695322
# [3200]	valid_0's rmse: 0.695296
# [3300]	valid_0's rmse: 0.695267
# [3400]	valid_0's rmse: 0.695261
# [3500]	valid_0's rmse: 0.695253
# [3600]	valid_0's rmse: 0.695253
# [3700]	valid_0's rmse: 0.695249
# [3800]	valid_0's rmse: 0.695244
# [3900]	valid_0's rmse: 0.695229
# [4000]	valid_0's rmse: 0.695218
# [4100]	valid_0's rmse: 0.695226
# [4200]	valid_0's rmse: 0.695224
# [4300]	valid_0's rmse: 0.695239
# [4400]	valid_0's rmse: 0.695238
# [4500]	valid_0's rmse: 0.695248
# [4600]	valid_0's rmse: 0.695254
# [4700]	valid_0's rmse: 0.695276
# [4800]	valid_0's rmse: 0.695272
# [4900]	valid_0's rmse: 0.695281
# [5000]	valid_0's rmse: 0.695307
# Did not meet early stopping. Best iteration is:
# [4054]	valid_0's rmse: 0.695202
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.722461
# [200]	valid_0's rmse: 0.714999
# [300]	valid_0's rmse: 0.710129
# [400]	valid_0's rmse: 0.706969
# [500]	valid_0's rmse: 0.704698
# [600]	valid_0's rmse: 0.703055
# [700]	valid_0's rmse: 0.70174
# [800]	valid_0's rmse: 0.700711
# [900]	valid_0's rmse: 0.699867
# [1000]	valid_0's rmse: 0.699223
# [1100]	valid_0's rmse: 0.698703
# [1200]	valid_0's rmse: 0.698321
# [1300]	valid_0's rmse: 0.697974
# [1400]	valid_0's rmse: 0.697686
# [1500]	valid_0's rmse: 0.697443
# [1600]	valid_0's rmse: 0.697245
# [1700]	valid_0's rmse: 0.697064
# [1800]	valid_0's rmse: 0.696896
# [1900]	valid_0's rmse: 0.696787
# [2000]	valid_0's rmse: 0.696677
# [2100]	valid_0's rmse: 0.696596
# [2200]	valid_0's rmse: 0.696503
# [2300]	valid_0's rmse: 0.696451
# [2400]	valid_0's rmse: 0.696398
# [2500]	valid_0's rmse: 0.696324
# [2600]	valid_0's rmse: 0.696277
# [2700]	valid_0's rmse: 0.696246
# [2800]	valid_0's rmse: 0.696204
# [2900]	valid_0's rmse: 0.696196
# [3000]	valid_0's rmse: 0.696169
# [3100]	valid_0's rmse: 0.69613
# [3200]	valid_0's rmse: 0.696097
# [3300]	valid_0's rmse: 0.696082
# [3400]	valid_0's rmse: 0.696065
# [3500]	valid_0's rmse: 0.696051
# [3600]	valid_0's rmse: 0.696065
# [3700]	valid_0's rmse: 0.696083
# [3800]	valid_0's rmse: 0.696079
# [3900]	valid_0's rmse: 0.696075
# [4000]	valid_0's rmse: 0.696092
# [4100]	valid_0's rmse: 0.696099
# [4200]	valid_0's rmse: 0.696111
# [4300]	valid_0's rmse: 0.696126
# [4400]	valid_0's rmse: 0.696123
# [4500]	valid_0's rmse: 0.696139
# Early stopping, best iteration is:
# [3510]	valid_0's rmse: 0.696043
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.721784
# [200]	valid_0's rmse: 0.7145
# [300]	valid_0's rmse: 0.709736
# [400]	valid_0's rmse: 0.70663
# [500]	valid_0's rmse: 0.704382
# [600]	valid_0's rmse: 0.702743
# [700]	valid_0's rmse: 0.701429
# [800]	valid_0's rmse: 0.700385
# [900]	valid_0's rmse: 0.699523
# [1000]	valid_0's rmse: 0.69878
# [1100]	valid_0's rmse: 0.698213
# [1200]	valid_0's rmse: 0.697739
# [1300]	valid_0's rmse: 0.697349
# [1400]	valid_0's rmse: 0.697025
# [1500]	valid_0's rmse: 0.696735
# [1600]	valid_0's rmse: 0.696526
# [1700]	valid_0's rmse: 0.696331
# [1800]	valid_0's rmse: 0.696168
# [1900]	valid_0's rmse: 0.695995
# [2000]	valid_0's rmse: 0.695873
# [2100]	valid_0's rmse: 0.69574
# [2200]	valid_0's rmse: 0.69566
# [2300]	valid_0's rmse: 0.695577
# [2400]	valid_0's rmse: 0.695537
# [2500]	valid_0's rmse: 0.695449
# [2600]	valid_0's rmse: 0.695391
# [2700]	valid_0's rmse: 0.695343
# [2800]	valid_0's rmse: 0.695288
# [2900]	valid_0's rmse: 0.695224
# [3000]	valid_0's rmse: 0.695183
# [3100]	valid_0's rmse: 0.695129
# [3200]	valid_0's rmse: 0.695107
# [3300]	valid_0's rmse: 0.695061
# [3400]	valid_0's rmse: 0.695069
# [3500]	valid_0's rmse: 0.695061
# [3600]	valid_0's rmse: 0.695066
# [3700]	valid_0's rmse: 0.695038
# [3800]	valid_0's rmse: 0.695037
# [3900]	valid_0's rmse: 0.695013
# [4000]	valid_0's rmse: 0.695019
# [4100]	valid_0's rmse: 0.694992
# [4200]	valid_0's rmse: 0.695015
# [4300]	valid_0's rmse: 0.695014
# [4400]	valid_0's rmse: 0.694995
# [4500]	valid_0's rmse: 0.695015
# [4600]	valid_0's rmse: 0.69503
# [4700]	valid_0's rmse: 0.695048
# [4800]	valid_0's rmse: 0.69505
# [4900]	valid_0's rmse: 0.695058
# [5000]	valid_0's rmse: 0.695078
# Did not meet early stopping. Best iteration is:
# [4116]	valid_0's rmse: 0.694984
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.724152
# [200]	valid_0's rmse: 0.716793
# [300]	valid_0's rmse: 0.711982
# [400]	valid_0's rmse: 0.708809
# [500]	valid_0's rmse: 0.706504
# [600]	valid_0's rmse: 0.704795
# [700]	valid_0's rmse: 0.703427
# [800]	valid_0's rmse: 0.702362
# [900]	valid_0's rmse: 0.701518
# [1000]	valid_0's rmse: 0.700858
# [1100]	valid_0's rmse: 0.700265
# [1200]	valid_0's rmse: 0.699791
# [1300]	valid_0's rmse: 0.699391
# [1400]	valid_0's rmse: 0.699085
# [1500]	valid_0's rmse: 0.698838
# [1600]	valid_0's rmse: 0.698626
# [1700]	valid_0's rmse: 0.698451
# [1800]	valid_0's rmse: 0.698294
# [1900]	valid_0's rmse: 0.698173
# [2000]	valid_0's rmse: 0.698084
# [2100]	valid_0's rmse: 0.697989
# [2200]	valid_0's rmse: 0.697916
# [2300]	valid_0's rmse: 0.69783
# [2400]	valid_0's rmse: 0.697753
# [2500]	valid_0's rmse: 0.697705
# [2600]	valid_0's rmse: 0.697626
# [2700]	valid_0's rmse: 0.697602
# [2800]	valid_0's rmse: 0.697569
# [2900]	valid_0's rmse: 0.697554
# [3000]	valid_0's rmse: 0.697527
# [3100]	valid_0's rmse: 0.697522
# [3200]	valid_0's rmse: 0.697529
# [3300]	valid_0's rmse: 0.697522
# [3400]	valid_0's rmse: 0.697504
# [3500]	valid_0's rmse: 0.697482
# [3600]	valid_0's rmse: 0.697463
# [3700]	valid_0's rmse: 0.697479
# [3800]	valid_0's rmse: 0.697486
# [3900]	valid_0's rmse: 0.697484
# [4000]	valid_0's rmse: 0.697499
# [4100]	valid_0's rmse: 0.697503
# [4200]	valid_0's rmse: 0.69749
# [4300]	valid_0's rmse: 0.697502
# [4400]	valid_0's rmse: 0.697539
# [4500]	valid_0's rmse: 0.69756
# Early stopping, best iteration is:
# [3590]	valid_0's rmse: 0.697459
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.720807
# [200]	valid_0's rmse: 0.714113
# [300]	valid_0's rmse: 0.7098
# [400]	valid_0's rmse: 0.707013
# [500]	valid_0's rmse: 0.705053
# [600]	valid_0's rmse: 0.703625
# [700]	valid_0's rmse: 0.702452
# [800]	valid_0's rmse: 0.701548
# [900]	valid_0's rmse: 0.700836
# [1000]	valid_0's rmse: 0.700274
# [1100]	valid_0's rmse: 0.699798
# [1200]	valid_0's rmse: 0.699432
# [1300]	valid_0's rmse: 0.699108
# [1400]	valid_0's rmse: 0.698876
# [1500]	valid_0's rmse: 0.698647
# [1600]	valid_0's rmse: 0.69847
# [1700]	valid_0's rmse: 0.698303
# [1800]	valid_0's rmse: 0.698172
# [1900]	valid_0's rmse: 0.698057
# [2000]	valid_0's rmse: 0.697986
# [2100]	valid_0's rmse: 0.69793
# [2200]	valid_0's rmse: 0.697904
# [2300]	valid_0's rmse: 0.697844
# [2400]	valid_0's rmse: 0.697803
# [2500]	valid_0's rmse: 0.697742
# [2600]	valid_0's rmse: 0.697713
# [2700]	valid_0's rmse: 0.697691
# [2800]	valid_0's rmse: 0.697657
# [2900]	valid_0's rmse: 0.697633
# [3000]	valid_0's rmse: 0.697633
# [3100]	valid_0's rmse: 0.697629
# [3200]	valid_0's rmse: 0.697636
# [3300]	valid_0's rmse: 0.697617
# [3400]	valid_0's rmse: 0.697575
# [3500]	valid_0's rmse: 0.69756
# [3600]	valid_0's rmse: 0.697572
# [3700]	valid_0's rmse: 0.697567
# [3800]	valid_0's rmse: 0.697551
# [3900]	valid_0's rmse: 0.697562
# [4000]	valid_0's rmse: 0.697554
# [4100]	valid_0's rmse: 0.697562
# [4200]	valid_0's rmse: 0.697569
# [4300]	valid_0's rmse: 0.697576
# [4400]	valid_0's rmse: 0.697578
# [4500]	valid_0's rmse: 0.697582
# [4600]	valid_0's rmse: 0.697615
# [4700]	valid_0's rmse: 0.697647
# [4800]	valid_0's rmse: 0.697675
# [4900]	valid_0's rmse: 0.697697
# Early stopping, best iteration is:
# [3927]	valid_0's rmse: 0.697543
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.72166
# [200]	valid_0's rmse: 0.714378
# [300]	valid_0's rmse: 0.7096
# [400]	valid_0's rmse: 0.706387
# [500]	valid_0's rmse: 0.704087
# [600]	valid_0's rmse: 0.702388
# [700]	valid_0's rmse: 0.701078
# [800]	valid_0's rmse: 0.700017
# [900]	valid_0's rmse: 0.699139
# [1000]	valid_0's rmse: 0.698428
# [1100]	valid_0's rmse: 0.697915
# [1200]	valid_0's rmse: 0.697468
# [1300]	valid_0's rmse: 0.697076
# [1400]	valid_0's rmse: 0.696779
# [1500]	valid_0's rmse: 0.696537
# [1600]	valid_0's rmse: 0.696337
# [1700]	valid_0's rmse: 0.696155
# [1800]	valid_0's rmse: 0.696025
# [1900]	valid_0's rmse: 0.695901
# [2000]	valid_0's rmse: 0.695781
# [2100]	valid_0's rmse: 0.695681
# [2200]	valid_0's rmse: 0.69562
# [2300]	valid_0's rmse: 0.695557
# [2400]	valid_0's rmse: 0.695496
# [2500]	valid_0's rmse: 0.695449
# [2600]	valid_0's rmse: 0.695407
# [2700]	valid_0's rmse: 0.695392
# [2800]	valid_0's rmse: 0.695367
# [2900]	valid_0's rmse: 0.695346
# [3000]	valid_0's rmse: 0.695313
# [3100]	valid_0's rmse: 0.695286
# [3200]	valid_0's rmse: 0.695275
# [3300]	valid_0's rmse: 0.695258
# [3400]	valid_0's rmse: 0.695252
# [3500]	valid_0's rmse: 0.695253
# [3600]	valid_0's rmse: 0.695254
# [3700]	valid_0's rmse: 0.695287
# [3800]	valid_0's rmse: 0.695285
# [3900]	valid_0's rmse: 0.695299
# [4000]	valid_0's rmse: 0.695322
# [4100]	valid_0's rmse: 0.695337
# [4200]	valid_0's rmse: 0.695344
# [4300]	valid_0's rmse: 0.69537
# [4400]	valid_0's rmse: 0.695379
# Early stopping, best iteration is:
# [3463]	valid_0's rmse: 0.695241
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's rmse: 0.718893
# [200]	valid_0's rmse: 0.711916
# [300]	valid_0's rmse: 0.707388
# [400]	valid_0's rmse: 0.704406
# [500]	valid_0's rmse: 0.702325
# [600]	valid_0's rmse: 0.70082
# [700]	valid_0's rmse: 0.699597
# [800]	valid_0's rmse: 0.698606
# [900]	valid_0's rmse: 0.697812
# [1000]	valid_0's rmse: 0.697175
# [1100]	valid_0's rmse: 0.696645
# [1200]	valid_0's rmse: 0.696183
# [1300]	valid_0's rmse: 0.69584
# [1400]	valid_0's rmse: 0.695557
# [1500]	valid_0's rmse: 0.695328
# [1600]	valid_0's rmse: 0.695131
# [1700]	valid_0's rmse: 0.694952
# [1800]	valid_0's rmse: 0.694768
# [1900]	valid_0's rmse: 0.694648
# [2000]	valid_0's rmse: 0.694533
# [2100]	valid_0's rmse: 0.69445
# [2200]	valid_0's rmse: 0.694397
# [2300]	valid_0's rmse: 0.694319
# [2400]	valid_0's rmse: 0.694268
# [2500]	valid_0's rmse: 0.694212
# [2600]	valid_0's rmse: 0.694142
# [2700]	valid_0's rmse: 0.694116
# [2800]	valid_0's rmse: 0.69409
# [2900]	valid_0's rmse: 0.694063
# [3000]	valid_0's rmse: 0.694066
# [3100]	valid_0's rmse: 0.694026
# [3200]	valid_0's rmse: 0.694014
# [3300]	valid_0's rmse: 0.694014
# [3400]	valid_0's rmse: 0.694005
# [3500]	valid_0's rmse: 0.694001
# [3600]	valid_0's rmse: 0.693989
# [3700]	valid_0's rmse: 0.694006
# [3800]	valid_0's rmse: 0.693993
# [3900]	valid_0's rmse: 0.694029
# [4000]	valid_0's rmse: 0.694026
# [4100]	valid_0's rmse: 0.694046
# [4200]	valid_0's rmse: 0.694052
# [4300]	valid_0's rmse: 0.69409
# [4400]	valid_0's rmse: 0.694113
# [4500]	valid_0's rmse: 0.694113
# [4600]	valid_0's rmse: 0.694147
# Early stopping, best iteration is:
# [3619]	valid_0's rmse: 0.693984

# %%
np.sqrt(mean_squared_error(df_train.target, folds_average_lgbm.oof_preds))
# Out:
# 0.6955880415125976

# %%
# y_pred = folds_average_lgbm.predict(test_x)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
sub = df_sample.copy()
sub["target"] = y_pred

sub.to_csv("C:/Users/gaurav sahani/Desktop/Kaggle Playgroud Series/submission_lgbm_fold_8_25_01.csv", index=False)

sub.head(10)
# Out:
#    id    target
# 0   0  7.957645
# 1   2  7.877215
# 2   6  7.933945
# 3   7  8.274540
# 4  10  8.115473
# 5  14  7.915965
# 6  16  8.272832
# 7  17  7.731470
# 8  18  7.850360
# 9  19  7.723274
