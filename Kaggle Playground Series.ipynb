# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  0.670390  0.811300  0.643968  0.291791  0.284117  0.855953  0.890700
# 1   3  0.388053  0.621104  0.686102  0.501149  0.643790  0.449805  0.510824
# 2   4  0.834950  0.227436  0.301584  0.293408  0.606839  0.829175  0.506143
# 3   5  0.820708  0.160155  0.546887  0.726104  0.282444  0.785108  0.752758
# 4   8  0.935278  0.421235  0.303801  0.880214  0.665610  0.830131  0.487113
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14  \
# 0  0.285542  0.558245  0.779418  0.921832  0.866772  0.878733  0.305411
# 1  0.580748  0.418335  0.432632  0.439872  0.434971  0.369957  0.369484
# 2  0.558771  0.587603  0.823312  0.567007  0.677708  0.882938  0.303047
# 3  0.823267  0.574466  0.580843  0.769594  0.818143  0.914281  0.279528
# 4  0.604157  0.874658  0.863427  0.983575  0.900464  0.935918  0.435772
#
#      target
# 0  7.243043
# 1  8.203331
# 2  7.776091
# 3  6.957716
# ...

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   0  0.353600  0.738780  0.600939  0.293377  0.285691  0.458006  0.620704
# 1   2  0.907222  0.189756  0.215531  0.869915  0.301333  0.528958  0.390351
# 2   6  0.179287  0.355353  0.623972  0.437812  0.282476  0.320826  0.386789
# 3   7  0.359385  0.181049  0.551368  0.206386  0.280763  0.482076  0.506677
# 4  10  0.335791  0.682607  0.676481  0.219465  0.282861  0.581721  0.748639
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14
# 0  0.422249  0.369203  0.435727  0.550540  0.699134  0.286864  0.364515
# 1  0.521112  0.794779  0.798580  0.446475  0.449037  0.916964  0.513002
# 2  0.776422  0.222268  0.229102  0.211913  0.222651  0.327164  0.827941
# 3  0.362793  0.379737  0.345686  0.445276  0.518485  0.299028  0.598166
# 4  0.350158  0.448915  0.506878  0.817721  0.805895  0.790591  0.249275

# %%
df_testing = pd.read_csv('test.csv')
#df_testing.head()

# %%
print(df_train.isnull().sum())
print(df_test.isnull().sum())
# Out:
# id        0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# cont11    0
# cont12    0
# cont13    0
# cont14    0
# target    0
# dtype: int64
# id        0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# cont11    0
# cont12    0
# cont13    0
# cont14    0
# dtype: int64

# %%
df_train.describe()
# Out:
#                   id          cont1          cont2          cont3  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   249825.145857       0.506873       0.497898       0.521557
# std    144476.732562       0.203976       0.228159       0.200770
# min         1.000000      -0.082263      -0.031397       0.020967
# 25%    124656.500000       0.343078       0.319170       0.344096
# 50%    249738.500000       0.484005       0.553209       0.551471
# 75%    374836.250000       0.643789       0.731263       0.648315
# max    499999.000000       1.016227       0.859697       1.006955
#
#                cont4          cont5          cont6          cont7  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.515683       0.502022       0.526515       0.487890
# std         0.233035       0.220701       0.217909       0.181096
# min         0.152761       0.276377       0.066166      -0.097666
# ...

# %%
df_train.drop(['id'],axis=1,inplace=True)
df_test.drop(['id'],axis=1,inplace=True)

# %%
df_train.hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016EAF429948>,
# ...
#       dtype=object)

# %%
df_test.hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016EB2A66F88>,
# ...
#       dtype=object)

# %%
print(df_train.info())
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   cont1   300000 non-null  float64
#  1   cont2   300000 non-null  float64
#  2   cont3   300000 non-null  float64
#  3   cont4   300000 non-null  float64
#  4   cont5   300000 non-null  float64
#  5   cont6   300000 non-null  float64
#  6   cont7   300000 non-null  float64
#  7   cont8   300000 non-null  float64
#  8   cont9   300000 non-null  float64
#  9   cont10  300000 non-null  float64
#  10  cont11  300000 non-null  float64
#  11  cont12  300000 non-null  float64
#  12  cont13  300000 non-null  float64
#  13  cont14  300000 non-null  float64
#  14  target  300000 non-null  float64
# dtypes: float64(15)
# memory usage: 34.3 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 14 columns):
# ...

# %%
df_train.skew()
# Out:
# cont1     0.529578
# cont2    -0.248080
# cont3     0.009037
# cont4     0.250383
# cont5     0.610304
# cont6     0.537976
# cont7     0.703412
# cont8     0.569728
# cont9     0.796233
# cont10    0.362601
# cont11    0.419389
# cont12    0.283174
# cont13    0.320349
# cont14    0.252548
# target   -0.077399
# dtype: float64

# %%
df_test.skew()
# Out:
# cont1     0.519347
# cont2    -0.245483
# cont3     0.005117
# cont4     0.254502
# cont5     0.607924
# cont6     0.540047
# cont7     0.702166
# cont8     0.568772
# cont9     0.800410
# cont10    0.364131
# cont11    0.423284
# cont12    0.284890
# cont13    0.315861
# cont14    0.254286
# dtype: float64

# %%
df_train.corr()
# Out:
#            cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# cont1   1.000000 -0.080170 -0.419712  0.273705 -0.059012  0.698556  0.341478
# cont2  -0.080170  1.000000  0.334487 -0.005533  0.150737  0.023692  0.116222
# cont3  -0.419712  0.334487  1.000000 -0.329131  0.060931 -0.300509  0.106904
# cont4   0.273705 -0.005533 -0.329131  1.000000  0.123526  0.152752 -0.077045
# cont5  -0.059012  0.150737  0.060931  0.123526  1.000000 -0.179084 -0.241272
# cont6   0.698556  0.023692 -0.300509  0.152752 -0.179084  1.000000  0.541975
# cont7   0.341478  0.116222  0.106904 -0.077045 -0.241272  0.541975  1.000000
# cont8   0.373340  0.081049 -0.309783  0.324784  0.010438  0.415008  0.150403
# cont9   0.794003 -0.046769 -0.406743  0.261927 -0.071764  0.716613  0.341759
# cont10  0.725040  0.035101 -0.289756  0.204139 -0.102531  0.770628  0.465418
# cont11  0.565717  0.126024 -0.075415  0.063961 -0.222244  0.737495  0.672188
# ...

# %%
corr = df_train.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr, vmax=0.9, cmap="inferno", square=True)

# %%
corr = df_test.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr, vmax=0.9, cmap="inferno", square=True)

# %%
X=df_train.drop(['target'],axis=1)
y=df_train.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.18, random_state=2)

# %%
#REgressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import StackingRegressor
from catboost import CatBoostRegressor
#Evalution Metrix
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

# %%
et = ExtraTreesRegressor(n_jobs=-1,n_estimators=500)
rf = RandomForestRegressor(max_depth=8,bootstrap=True,n_jobs=-1,n_estimators=200,max_features='sqrt')
xgb = xgboost.XGBRegressor(n_jobs=-1,colsample_bytree=0.7, learning_rate=0.07,max_depth=5, min_child_weight=4, n_estimators=500,nthread=4, subsample=0.7)
gbr = GradientBoostingRegressor(random_state=0)
xgb = xgboost.XGBRegressor(n_jobs=-1)
et = ExtraTreesRegressor(n_jobs=-1)
rf = RandomForestRegressor(n_jobs=-1)
ds = DecisionTreeRegressor()

# %%
reg = {
"LinearRegression": LinearRegression(),
"KNeighborsRegressor":KNeighborsRegressor(n_neighbors=2),
"AdaBoostRegressor":AdaBoostRegressor(random_state=0, n_estimators=100),
"LGBMRegressor":LGBMRegressor(),
"Ridge": Ridge(alpha=1.0),
"ElasticNet":ElasticNet(random_state=0),
"GradientBoostingRegressor":GradientBoostingRegressor(random_state=0),
"DecisionTreeRegressor": DecisionTreeRegressor(),
"ExtraTreesRegressor": ExtraTreesRegressor(n_jobs=-1),
"RandomForestRegressor": RandomForestRegressor(n_jobs=-1),
"XGBRegressor":xgboost.XGBRegressor(n_jobs=-1),
"CatBoostRegressor":CatBoostRegressor(iterations=900, depth=5, learning_rate=0.05,loss_function = 'RMSE')
# "VotingRegressor": VotingRegressor([('rf', rf),('xgb',xgb),('et',et)],n_jobs=-1)
# "Stacking" : StackingRegressor(estimators=[('et', et),('xgb',xgb),('rf',rf)], final_estimator=LinearRegression(), cv=5)
}

# %%
# %%time
dic =  {"Model":[],"R2_Train":[],"RMSE_Train":[]}
for name, model in reg.items():
    if name == 'CatBoostRegressor':
        model.fit(X_train, y_train,verbose=False)
    else:
        model.fit(X_train, y_train)
    #y_test_pre = model.predict(test_df)
    y_train_pre = model.predict(X_test)
    r2_train = r2_score(y_test, y_train_pre)
    rmse_train  = np.sqrt(mean_squared_error(y_test, y_train_pre))
    print("--------------------------------------------------------------")
    print("Model:", name)
    print("-----Training Data Evalution-----")
    print("R2 Value: ", r2_score(y_test, y_train_pre))
    print("RMSE: ",np.sqrt(mean_squared_error(y_test, y_train_pre)))
    dic["Model"].append(name)
    dic["R2_Train"].append(r2_train)
    dic["RMSE_Train"].append(rmse_train)
#final_data = pd.DataFrame(dic)
#print("==================================================================")
#print("Best Model")
#print("==================================================================")
#print(final_data.max())
#print("==================================================================")
#final_data.sort_values("RMSE_Train", axis = 0, ascending = True)
# Out:
# --------------------------------------------------------------
# Model: LinearRegression
# -----Training Data Evalution-----
# R2 Value:  0.01934053896104093
# RMSE:  0.7276111218129682
# --------------------------------------------------------------
# Model: KNeighborsRegressor
# -----Training Data Evalution-----
# R2 Value:  -0.3628386662279095
# RMSE:  0.8577533855641198
# --------------------------------------------------------------
# Model: AdaBoostRegressor
# -----Training Data Evalution-----
# R2 Value:  0.017753699046101024
# RMSE:  0.7281995705651779
# --------------------------------------------------------------
# Model: LGBMRegressor
# -----Training Data Evalution-----
# R2 Value:  0.083009664653375
# RMSE:  0.7035947605030731
# --------------------------------------------------------------
# Model: Ridge
# -----Training Data Evalution-----
# R2 Value:  0.01934027645316383
# RMSE:  0.7276112191982715
# --------------------------------------------------------------
# ...

# %%
final_data = pd.DataFrame(dic)
final_data
# Out:
#                         Model  R2_Train  RMSE_Train
# 0            LinearRegression  0.019341    0.727611
# 1         KNeighborsRegressor -0.362839    0.857753
# 2           AdaBoostRegressor  0.017754    0.728200
# 3               LGBMRegressor  0.083010    0.703595
# 4                       Ridge  0.019340    0.727611
# 5                  ElasticNet -0.000036    0.734764
# 6   GradientBoostingRegressor  0.057804    0.713199
# 7       DecisionTreeRegressor -0.881823    1.007928
# 8         ExtraTreesRegressor  0.071302    0.708072
# 9       RandomForestRegressor  0.068415    0.709172
# 10               XGBRegressor  0.082698    0.703714
# 11          CatBoostRegressor  0.083762    0.703306

# %%
final_data.sort_values("RMSE_Train", axis = 0, ascending = True)
# Out:
#                         Model  R2_Train  RMSE_Train
# 11          CatBoostRegressor  0.083762    0.703306
# 3               LGBMRegressor  0.083010    0.703595
# 10               XGBRegressor  0.082698    0.703714
# 8         ExtraTreesRegressor  0.071302    0.708072
# 9       RandomForestRegressor  0.068415    0.709172
# 6   GradientBoostingRegressor  0.057804    0.713199
# 0            LinearRegression  0.019341    0.727611
# 4                       Ridge  0.019340    0.727611
# 2           AdaBoostRegressor  0.017754    0.728200
# 5                  ElasticNet -0.000036    0.734764
# 1         KNeighborsRegressor -0.362839    0.857753
# 7       DecisionTreeRegressor -0.881823    1.007928

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'depth'         : [6,8,10],
                  'learning_rate' : [0.01, 0.05, 0.1],
                  'iterations'    : [30, 50, 100]
                 }
CBR = CatBoostRegressor()

grid = GridSearchCV(estimator=CBR, param_grid = parameters, cv = 3, n_jobs=-1)
grid.fit(X, y)
CBR
print(" Results from Grid Search " )
print("\n The best estimator across ALL searched params:\n", grid.best_estimator_)
print("\n The best score across ALL searched params:\n", grid.best_score_)
print("\n The best parameters across ALL searched params:\n", grid.best_params_)
# Out:
# 0:	learn: 0.7304175	total: 121ms	remaining: 12s
# 1:	learn: 0.7280898	total: 232ms	remaining: 11.4s
# 2:	learn: 0.7261198	total: 350ms	remaining: 11.3s
# 3:	learn: 0.7244931	total: 482ms	remaining: 11.6s
# 4:	learn: 0.7231740	total: 631ms	remaining: 12s
# 5:	learn: 0.7219592	total: 744ms	remaining: 11.7s
# 6:	learn: 0.7208238	total: 864ms	remaining: 11.5s
# 7:	learn: 0.7198240	total: 977ms	remaining: 11.2s
# 8:	learn: 0.7189640	total: 1.1s	remaining: 11.1s
# 9:	learn: 0.7182336	total: 1.21s	remaining: 10.9s
# 10:	learn: 0.7175948	total: 1.33s	remaining: 10.7s
# 11:	learn: 0.7169602	total: 1.44s	remaining: 10.6s
# 12:	learn: 0.7162671	total: 1.56s	remaining: 10.4s
# 13:	learn: 0.7157494	total: 1.68s	remaining: 10.3s
# 14:	learn: 0.7152236	total: 1.82s	remaining: 10.3s
# 15:	learn: 0.7146542	total: 1.93s	remaining: 10.1s
# 16:	learn: 0.7140865	total: 2.06s	remaining: 10.1s
# 17:	learn: 0.7135446	total: 2.18s	remaining: 9.92s
# 18:	learn: 0.7131297	total: 2.3s	remaining: 9.8s
# ...

# %%
CBR_Test = CatBoostRegressor(depth=10, iterations=100, learning_rate=0.1)

CBR_Test.fit(X,y)
# Out:
# 0:	learn: 0.7304175	total: 99.1ms	remaining: 9.81s
# 1:	learn: 0.7280898	total: 197ms	remaining: 9.64s
# 2:	learn: 0.7261198	total: 299ms	remaining: 9.65s
# 3:	learn: 0.7244931	total: 403ms	remaining: 9.67s
# 4:	learn: 0.7231740	total: 511ms	remaining: 9.71s
# 5:	learn: 0.7219592	total: 612ms	remaining: 9.59s
# 6:	learn: 0.7208238	total: 715ms	remaining: 9.5s
# 7:	learn: 0.7198240	total: 830ms	remaining: 9.54s
# 8:	learn: 0.7189640	total: 933ms	remaining: 9.43s
# 9:	learn: 0.7182336	total: 1.06s	remaining: 9.55s
# 10:	learn: 0.7175948	total: 1.17s	remaining: 9.5s
# 11:	learn: 0.7169602	total: 1.27s	remaining: 9.34s
# 12:	learn: 0.7162671	total: 1.38s	remaining: 9.21s
# 13:	learn: 0.7157494	total: 1.49s	remaining: 9.13s
# 14:	learn: 0.7152236	total: 1.61s	remaining: 9.15s
# 15:	learn: 0.7146542	total: 1.72s	remaining: 9.04s
# 16:	learn: 0.7140865	total: 1.87s	remaining: 9.14s
# 17:	learn: 0.7135446	total: 2s	remaining: 9.13s
# 18:	learn: 0.7131297	total: 2.14s	remaining: 9.13s
# ...

# %%
pred_CBR = CBR_Test.predict(df_test)
pred_CBR
# Out:
# array([8.02215499, 7.82072979, 7.87434295, ..., 8.1180415 , 8.03201892,
#        7.9535186 ])

# %%
output = pd.DataFrame({'id': df_testing.id, 'target': pred_CBR})
output.to_csv('Kaggle_Playground_Submission_1.csv', index=False)
